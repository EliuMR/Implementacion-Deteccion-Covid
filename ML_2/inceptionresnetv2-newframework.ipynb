# %%
import glob 
import numpy as np 
import os 
import shutil 
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score,recall_score
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator,  load_img, img_to_array, array_to_img 
np.random.seed(42) 
#from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model 
from keras.applications.inception_resnet_v2 import preprocess_input
import keras 
import matplotlib.pyplot as plt 
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from keras.models import Sequential 
from keras import optimizers

# %%
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
IM_SHAPE=(299,299)
input_shape=(IM_SHAPE[0],IM_SHAPE[1],3)

# %%
batch_size = 32
num_classes = 2 
epochs = 32
train_datagen = ImageDataGenerator(rescale=1./255,
                                    preprocessing_function=preprocess_input,
                                      validation_split=0.3)
val_datagen=ImageDataGenerator(rescale=1./255,
                               preprocessing_function=preprocess_input,
                                      validation_split=0.2)

# train_generator = train_datagen.flow_from_directory(
#     '../input/covidog/dataset',
#     target_size=IM_SHAPE,

#     batch_size=batch_size,
#     class_mode='categorical') # set as training data

train_generator_NEW = train_datagen.flow_from_directory(
    '/kaggle/input/covidnew/ALL/Train', # same directory as training data
    target_size=IM_SHAPE,
    subset='training',
    batch_size=batch_size,
    class_mode='categorical') # set as validation data
validation_generator_NEW= train_datagen.flow_from_directory(
    '/kaggle/input/covidnew/ALL/Train',
#     batch_size=16,
    subset='validation',
    class_mode='categorical',
    target_size=IM_SHAPE
)
test_generator_NEW=val_datagen.flow_from_directory(
    '/kaggle/input/covidnew/ALL/Test',
    #batch_size=16,
    class_mode='categorical',
    target_size=IM_SHAPE
)
# Out:
# Found 14461 images belonging to 2 classes.
# Found 6196 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
#from keras.applications import DenseNet121

from keras.applications import inception_resnet_v2 
vgg =  inception_resnet_v2.InceptionResNetV2(include_top=False, weights='imagenet',  
                                     input_shape=input_shape) 

# we have removed the final part of the classifier pertaining to the VGG-16 model 
#since we will be building our own classifier and leveraging VGG as a feature extractor
output = vgg.layers[-1].output 
output = keras.layers.Flatten()(output) 
vgg_model = Model(vgg.input, output) 
vgg_model.trainable = False 
 
for layer in vgg_model.layers: 
    layer.trainable = False 

#vgg_model.summary()
# Out:
# 2023-01-30 01:29:11.654734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:11.759961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:11.760748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:11.762692: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-30 01:29:11.762970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:11.763665: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:11.764327: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:14.046902: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:14.047925: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:14.048729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-30 01:29:14.049426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219062272/219055592 [==============================] - 2s 0us/step
# 219070464/219055592 [==============================] - 2s 0us/step

# %%
# To verify that the layers of the VGG-16 model are frozen, we can use the following code:
import pandas as pd 
pd.set_option('max_colwidth', -1) 
 
layers = [(layer, layer.name, layer.trainable) for layer in 
           vgg_model.layers] 
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                                                        Layer Type  \
# 0    <keras.engine.input_layer.InputLayer object at 0x7f844849fdd0>
# 1    <keras.layers.convolutional.Conv2D object at 0x7f84433ea8d0>
# 2    <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f84464dd9d0>
# 3    <keras.layers.core.Activation object at 0x7f84433f2910>
# 4    <keras.layers.convolutional.Conv2D object at 0x7f84467bc450>
# ..                                                            ...
# 776  <keras.layers.core.Lambda object at 0x7f842442cf10>
# 777  <keras.layers.convolutional.Conv2D object at 0x7f8424424810>
# 778  <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f84244d87d0>
# 779  <keras.layers.core.Activation object at 0x7f842446df90>
# 780  <keras.layers.core.Flatten object at 0x7f8424361e90>
#
#               Layer Name  Layer Trainable
# 0    input_1              False
# 1    conv2d               False
# 2    batch_normalization  False
# 3    activation           False
# 4    conv2d_1             False
# ..        ...               ...
# 776  block8_10            False
# 777  conv_7b              False
# 778  conv_7b_bn           False
# 779  conv_7b_ac           False
# 780  flatten              False
#
# [781 rows x 3 columns]

# %%
print("Trainable layers:", vgg_model.trainable_weights)
# Out:
# Trainable layers: []

# %%
array_to_img(train_generator_NEW[0][0][0])
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
bottleneck_feature_example = vgg.predict(train_generator_NEW[0][0])
print(bottleneck_feature_example.shape) 
plt.imshow(bottleneck_feature_example[0][:,:,0])
# Out:
# 2023-01-30 01:29:21.467077: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-01-30 01:29:25.617705: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# (32, 8, 8, 1536)

# %%
model_TF = Sequential() 

model_TF.add(vgg_model) 
model_TF.add(Dense(1024, activation='relu')) 
model_TF.add(Dropout(0.25)) 
model_TF.add(Dense(512, activation='relu')) 
model_TF.add(Dropout(0.25))
model_TF.add(Dense(256, activation='relu')) 
model_TF.add(Dropout(0.25))
model_TF.add(Dense(num_classes, activation='sigmoid'))

model_TF.summary()

model_TF.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9), 
      loss = tf.keras.losses.CategoricalCrossentropy(from_logits = True),
      metrics=['accuracy',f1_m,precision_m, recall_m])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 98304)             54336736
# _________________________________________________________________
# dense (Dense)                (None, 1024)              100664320
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 155,657,698
# Trainable params: 101,320,962
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
# history_TF = model_TF.fit(train_generator_NEW, 
#                               epochs=15,  
#                               validation_data=validation_generator_NEW,  
#                               verbose=1)

# %%
history_TF = model_TF.fit(train_generator_NEW, 
                              epochs=15,  
                              validation_data=validation_generator_NEW,  
                              verbose=1)
# Out:
# Epoch 1/15
# 452/452 [==============================] - 248s 549ms/step - loss: 0.7013 - accuracy: 0.5408 - f1_m: 0.2941 - precision_m: 0.5481 - recall_m: 0.2197 - val_loss: 0.6731 - val_accuracy: 0.5392 - val_f1_m: 0.5441 - val_precision_m: 0.5762 - val_recall_m: 0.5162
# Epoch 2/15
# 452/452 [==============================] - 132s 292ms/step - loss: 0.6888 - accuracy: 0.5279 - f1_m: 0.4683 - precision_m: 0.5319 - recall_m: 0.4323 - val_loss: 0.6914 - val_accuracy: 0.5303 - val_f1_m: 0.5306 - val_precision_m: 0.5306 - val_recall_m: 0.5305
# Epoch 3/15
# 452/452 [==============================] - 131s 290ms/step - loss: 0.6915 - accuracy: 0.5292 - f1_m: 0.4869 - precision_m: 0.5300 - recall_m: 0.4657 - val_loss: 0.6914 - val_accuracy: 0.5303 - val_f1_m: 0.5301 - val_precision_m: 0.5301 - val_recall_m: 0.5300
# Epoch 4/15
# 452/452 [==============================] - 132s 291ms/step - loss: 0.6915 - accuracy: 0.5304 - f1_m: 0.5302 - precision_m: 0.5306 - recall_m: 0.5298 - val_loss: 0.6913 - val_accuracy: 0.5303 - val_f1_m: 0.5301 - val_precision_m: 0.5301 - val_recall_m: 0.5300
# Epoch 5/15
# 452/452 [==============================] - 131s 291ms/step - loss: 0.6898 - accuracy: 0.5363 - f1_m: 0.5262 - precision_m: 0.5381 - recall_m: 0.5173 - val_loss: 0.6918 - val_accuracy: 0.5302 - val_f1_m: 0.5300 - val_precision_m: 0.5301 - val_recall_m: 0.5300
# Epoch 6/15
# 452/452 [==============================] - 132s 292ms/step - loss: 0.6915 - accuracy: 0.5304 - f1_m: 0.5302 - precision_m: 0.5304 - recall_m: 0.5301 - val_loss: 0.6913 - val_accuracy: 0.5305 - val_f1_m: 0.5302 - val_precision_m: 0.5304 - val_recall_m: 0.5301
# Epoch 7/15
# 452/452 [==============================] - 130s 288ms/step - loss: 0.6848 - accuracy: 0.5581 - f1_m: 0.5496 - precision_m: 0.5587 - recall_m: 0.5418 - val_loss: 0.6499 - val_accuracy: 0.6929 - val_f1_m: 0.6913 - val_precision_m: 0.6957 - val_recall_m: 0.6870
# Epoch 8/15
# 452/452 [==============================] - 129s 285ms/step - loss: 0.6901 - accuracy: 0.5362 - f1_m: 0.5360 - precision_m: 0.5370 - recall_m: 0.5352 - val_loss: 0.6914 - val_accuracy: 0.5305 - val_f1_m: 0.5306 - val_precision_m: 0.5306 - val_recall_m: 0.5306
# Epoch 9/15
# 452/452 [==============================] - 127s 280ms/step - loss: 0.6914 - accuracy: 0.5303 - f1_m: 0.5303 - precision_m: 0.5303 - recall_m: 0.5303 - val_loss: 0.6914 - val_accuracy: 0.5303 - val_f1_m: 0.5304 - val_precision_m: 0.5304 - val_recall_m: 0.5304
# Epoch 10/15
# 452/452 [==============================] - 127s 280ms/step - loss: 0.6915 - accuracy: 0.5304 - f1_m: 0.5304 - precision_m: 0.5304 - recall_m: 0.5304 - val_loss: 0.6914 - val_accuracy: 0.5300 - val_f1_m: 0.5296 - val_precision_m: 0.5296 - val_recall_m: 0.5296
# Epoch 11/15
# 452/452 [==============================] - 127s 280ms/step - loss: 0.6914 - accuracy: 0.5305 - f1_m: 0.5305 - precision_m: 0.5305 - recall_m: 0.5305 - val_loss: 0.6914 - val_accuracy: 0.5303 - val_f1_m: 0.5302 - val_precision_m: 0.5302 - val_recall_m: 0.5302
# Epoch 12/15
# 452/452 [==============================] - 126s 278ms/step - loss: 0.6914 - accuracy: 0.5305 - f1_m: 0.5305 - precision_m: 0.5305 - recall_m: 0.5304 - val_loss: 0.6914 - val_accuracy: 0.5305 - val_f1_m: 0.5307 - val_precision_m: 0.5307 - val_recall_m: 0.5307
# Epoch 13/15
# 452/452 [==============================] - 125s 277ms/step - loss: 0.6914 - accuracy: 0.5305 - f1_m: 0.5306 - precision_m: 0.5306 - recall_m: 0.5306 - val_loss: 0.6915 - val_accuracy: 0.5299 - val_f1_m: 0.5295 - val_precision_m: 0.5295 - val_recall_m: 0.5295
# Epoch 14/15
# 452/452 [==============================] - 127s 281ms/step - loss: 0.6900 - accuracy: 0.5370 - f1_m: 0.5367 - precision_m: 0.5370 - recall_m: 0.5363 - val_loss: 0.6914 - val_accuracy: 0.5305 - val_f1_m: 0.5303 - val_precision_m: 0.5303 - val_recall_m: 0.5303
# Epoch 15/15
# 452/452 [==============================] - 127s 280ms/step - loss: 0.6914 - accuracy: 0.5305 - f1_m: 0.5304 - precision_m: 0.5304 - recall_m: 0.5304 - val_loss: 0.6915 - val_accuracy: 0.5303 - val_f1_m: 0.5301 - val_precision_m: 0.5301 - val_recall_m: 0.5301

# %%
plt.plot(history_TF.history['f1_m'])
plt.plot(history_TF.history['val_f1_m'])
plt.title('F1 Score')
plt.ylabel('f1')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
test_loss= model_TF.evaluate(test_generator_NEW, verbose=1)
# Out:
# 63/63 [==============================] - 26s 407ms/step - loss: 0.6941 - accuracy: 0.5005 - f1_m: 0.4995 - precision_m: 0.4995 - recall_m: 0.4995

# %%
test_loss
# Out:
# [0.6941359639167786,
#  0.5005000233650208,
#  0.4995039403438568,
#  0.4995039701461792,
#  0.4995039701461792]

# %%
from keras.applications import inception_resnet_v2 
dense =  inception_resnet_v2.InceptionResNetV2(include_top=False,  
                                     input_shape=input_shape) 
output = dense.layers[-1].output 
output = keras.layers.Flatten()(output) 
dense_model = Model(dense.input, output) 
dense_model.trainable = True

# %%
model = Sequential() 

model.add(dense_model) 
model.add(Dense(1024, activation='relu')) 
model.add(Dropout(0.25)) 
model.add(Dense(512, activation='relu')) 
model.add(Dropout(0.25))
model.add(Dense(256, activation='relu')) 
model.add(Dropout(0.25))
model.add(Dense(num_classes, activation='sigmoid'))



model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9), 
      loss = tf.keras.losses.CategoricalCrossentropy(from_logits = True),
      metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 98304)             54336736
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              100664320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 155,657,698
# Trainable params: 155,597,154
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
history = model.fit(train_generator_NEW, 
                              epochs=15,  
                              validation_data=validation_generator_NEW,  
                              verbose=1)
# Out:
# Epoch 1/15
# 452/452 [==============================] - 317s 667ms/step - loss: 0.1844 - accuracy: 0.9240 - f1_m: 0.8902 - precision_m: 0.9418 - recall_m: 0.8478 - val_loss: 1.0400 - val_accuracy: 0.4314 - val_f1_m: 0.3917 - val_precision_m: 0.4269 - val_recall_m: 0.3634
# Epoch 2/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0468 - accuracy: 0.9823 - f1_m: 0.9742 - precision_m: 0.9896 - recall_m: 0.9598 - val_loss: 0.1584 - val_accuracy: 0.9579 - val_f1_m: 0.9535 - val_precision_m: 0.9643 - val_recall_m: 0.9433
# Epoch 3/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0146 - accuracy: 0.9956 - f1_m: 0.9914 - precision_m: 0.9975 - recall_m: 0.9855 - val_loss: 0.1519 - val_accuracy: 0.9597 - val_f1_m: 0.9548 - val_precision_m: 0.9712 - val_recall_m: 0.9395
# Epoch 4/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0113 - accuracy: 0.9961 - f1_m: 0.9922 - precision_m: 0.9984 - recall_m: 0.9862 - val_loss: 0.4276 - val_accuracy: 0.8935 - val_f1_m: 0.8719 - val_precision_m: 0.9223 - val_recall_m: 0.8282
# Epoch 5/15
# 452/452 [==============================] - 297s 657ms/step - loss: 0.0038 - accuracy: 0.9989 - f1_m: 0.9973 - precision_m: 0.9994 - recall_m: 0.9953 - val_loss: 0.1027 - val_accuracy: 0.9781 - val_f1_m: 0.9760 - val_precision_m: 0.9821 - val_recall_m: 0.9702
# Epoch 6/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0067 - accuracy: 0.9979 - f1_m: 0.9960 - precision_m: 0.9989 - recall_m: 0.9932 - val_loss: 0.1582 - val_accuracy: 0.9693 - val_f1_m: 0.9671 - val_precision_m: 0.9727 - val_recall_m: 0.9617
# Epoch 7/15
# 452/452 [==============================] - 297s 657ms/step - loss: 0.0050 - accuracy: 0.9987 - f1_m: 0.9975 - precision_m: 0.9991 - recall_m: 0.9961 - val_loss: 0.0698 - val_accuracy: 0.9834 - val_f1_m: 0.9833 - val_precision_m: 0.9866 - val_recall_m: 0.9802
# Epoch 8/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0028 - accuracy: 0.9992 - f1_m: 0.9984 - precision_m: 0.9995 - recall_m: 0.9972 - val_loss: 0.1425 - val_accuracy: 0.9711 - val_f1_m: 0.9699 - val_precision_m: 0.9758 - val_recall_m: 0.9642
# Epoch 9/15
# 452/452 [==============================] - 296s 656ms/step - loss: 0.0029 - accuracy: 0.9990 - f1_m: 0.9980 - precision_m: 0.9996 - recall_m: 0.9965 - val_loss: 0.1177 - val_accuracy: 0.9803 - val_f1_m: 0.9789 - val_precision_m: 0.9825 - val_recall_m: 0.9755
# Epoch 10/15
# 452/452 [==============================] - 296s 654ms/step - loss: 0.0075 - accuracy: 0.9973 - f1_m: 0.9964 - precision_m: 0.9984 - recall_m: 0.9945 - val_loss: 0.5344 - val_accuracy: 0.9238 - val_f1_m: 0.9236 - val_precision_m: 0.9302 - val_recall_m: 0.9174
# Epoch 11/15
# 452/452 [==============================] - 297s 657ms/step - loss: 0.0026 - accuracy: 0.9992 - f1_m: 0.9987 - precision_m: 0.9992 - recall_m: 0.9983 - val_loss: 0.8353 - val_accuracy: 0.8110 - val_f1_m: 0.8079 - val_precision_m: 0.8262 - val_recall_m: 0.7910
# Epoch 12/15
# 452/452 [==============================] - 296s 654ms/step - loss: 0.0033 - accuracy: 0.9984 - f1_m: 0.9981 - precision_m: 0.9990 - recall_m: 0.9974 - val_loss: 0.1319 - val_accuracy: 0.9690 - val_f1_m: 0.9689 - val_precision_m: 0.9719 - val_recall_m: 0.9661
# Epoch 13/15
# 452/452 [==============================] - 296s 656ms/step - loss: 0.0030 - accuracy: 0.9990 - f1_m: 0.9986 - precision_m: 0.9994 - recall_m: 0.9977 - val_loss: 0.0937 - val_accuracy: 0.9824 - val_f1_m: 0.9824 - val_precision_m: 0.9839 - val_recall_m: 0.9810
# Epoch 14/15
# 452/452 [==============================] - 296s 655ms/step - loss: 0.0027 - accuracy: 0.9990 - f1_m: 0.9986 - precision_m: 0.9994 - recall_m: 0.9978 - val_loss: 0.0804 - val_accuracy: 0.9850 - val_f1_m: 0.9850 - val_precision_m: 0.9869 - val_recall_m: 0.9831
# Epoch 15/15
# 452/452 [==============================] - 297s 657ms/step - loss: 0.0012 - accuracy: 0.9996 - f1_m: 0.9993 - precision_m: 0.9996 - recall_m: 0.9990 - val_loss: 0.0889 - val_accuracy: 0.9852 - val_f1_m: 0.9846 - val_precision_m: 0.9864 - val_recall_m: 0.9829

# %%
plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])
plt.title('F1 Score')
plt.ylabel('f1')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
test_loss= model.evaluate(test_generator_NEW, verbose=1)
# Out:
# 63/63 [==============================] - 14s 218ms/step - loss: 0.0944 - accuracy: 0.9810 - f1_m: 0.9801 - precision_m: 0.9825 - recall_m: 0.9777

# %%
test_loss
# Out:
# [0.09436170756816864,
#  0.9810000061988831,
#  0.9800558686256409,
#  0.9825258255004883,
#  0.9776785969734192]
