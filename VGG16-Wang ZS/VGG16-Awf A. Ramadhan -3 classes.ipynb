# %%
train_dir = 'D:/Documentos/Estudio/Maestría/Aprendizaje_Computacional/Modelopropio/Database/Lung Segmentation Data/Lung Segmentation Data-copia/Train' 
val_dir = 'D:/Documentos/Estudio/Maestría/Aprendizaje_Computacional/Modelopropio/Database/Lung Segmentation Data/Lung Segmentation Data-copia/Val' 
test_dir = 'D:/Documentos/Estudio/Maestría/Aprendizaje_Computacional/Modelopropio/Database/Lung Segmentation Data/Lung Segmentation Data-copia/Test'

# %%
#ELEGIMOS LOS PARAMETROS
from keras.preprocessing.image import ImageDataGenerator
#(100, 100, 3)
ih, iw = 100, 100 #tamano de la imagen
input_shape = (ih, iw, 3) #forma de la imagen: alto ancho y numero de canales

num_class = 3 #cuantas clases 
#epochs = 15 #cuantas veces entrenar. En cada epoch hace una mejora en los parametros

batch_size = 32 #batch para hacer cada entrenamiento. Lee 50 'batch_size' imagenes antes de actualizar los parametros. Las carga a memoria
num_train = 21715 #numero de imagenes en train
num_test = 6788 #numero de imagenes en test
num_val=5417

epoch_steps = num_train // batch_size 
test_steps = num_test // batch_size
# Out:
# Using TensorFlow backend.

# %%
#LEEMOS LAS IMÁGENES 

img_height, img_width=ih, iw

train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical') # set as training data

validation_generator = train_datagen.flow_from_directory(
    val_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical') # set as validation data

test_generator = train_datagen.flow_from_directory(
    test_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical') # set as validation data
# Out:
# Found 21715 images belonging to 3 classes.
# Found 5417 images belonging to 3 classes.
# Found 6788 images belonging to 3 classes.

# %%
train=train_generator
val=validation_generator
test=test_generator

# %%
from keras.applications import vgg16 
from keras.models import Model 
import keras 


vgg = vgg16.VGG16(include_top=False, weights='imagenet',  
                                     input_shape=input_shape) 

# we have removed the final part of the classifier pertaining to the VGG-16 model 
#since we will be building our own classifier and leveraging VGG as a feature extractor
output = vgg.layers[-5].output 
output = keras.layers.Flatten()(output) 
vgg_model = Model(vgg.input, output) 

 
vgg_model.trainable = True 
#set_trainable = False
 
#for layer in vgg_model.layers: 
#    if layer.name in ['block5_conv1', 'block4_conv1']: 
#        set_trainable = True 
#    if set_trainable: 
#        layer.trainable = True 
#    else: 
#        layer.trainable = False

# %%
import pandas as pd 
pd.set_option('max_colwidth', -1)

layers = [(layer, layer.name, layer.trainable) for layer in vgg_model.layers] 
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# C:\Users\elium\.conda\envs\tfGPU\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                             Layer Type  \
# 0   <keras.engine.input_layer.InputLayer object at 0x0000022C123E7A88>
# 1   <keras.layers.convolutional.Conv2D object at 0x0000022C10A41588>
# 2   <keras.layers.convolutional.Conv2D object at 0x0000022C123E7A48>
# 3   <keras.layers.pooling.MaxPooling2D object at 0x0000022C130CA548>
# 4   <keras.layers.convolutional.Conv2D object at 0x0000022C130CADC8>
# 5   <keras.layers.convolutional.Conv2D object at 0x0000022C13128888>
# 6   <keras.layers.pooling.MaxPooling2D object at 0x0000022C13128688>
# 7   <keras.layers.convolutional.Conv2D object at 0x0000022C1312C2C8>
# 8   <keras.layers.convolutional.Conv2D object at 0x0000022C13137E08>
# 9   <keras.layers.convolutional.Conv2D object at 0x0000022C1313EB48>
# 10  <keras.layers.pooling.MaxPooling2D object at 0x0000022C13142E48>
# 11  <keras.layers.convolutional.Conv2D object at 0x0000022C131466C8>
# 12  <keras.layers.convolutional.Conv2D object at 0x0000022C1314ACC8>
# 13  <keras.layers.convolutional.Conv2D object at 0x0000022C13153708>
# 14  <keras.layers.pooling.MaxPooling2D object at 0x0000022C1315A9C8>
# 15  <keras.layers.core.Flatten object at 0x0000022C123E75C8>
#
#       Layer Name  Layer Trainable
# 0   input_1       False
# 1   block1_conv1  True
# 2   block1_conv2  True
# 3   block1_pool   True
# 4   block2_conv1  True
# 5   block2_conv2  True
# 6   block2_pool   True
# 7   block3_conv1  True
# 8   block3_conv2  True
# 9   block3_conv3  True
# 10  block3_pool   True
# 11  block4_conv1  True
# 12  block4_conv2  True
# 13  block4_conv3  True
# 14  block4_pool   True
# 15  flatten_1     True

# %%
from os import listdir
from os.path import isfile,isdir, join
import numpy

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from keras import layers, models
from keras.models import Sequential
from keras.layers import Dense,Conv2D, Dropout,Activation,MaxPooling2D,Flatten
from keras.optimizers import RMSprop 
from sklearn.model_selection import train_test_split

# %%
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer 
from keras.models import Sequential 
from keras import optimizers  
import tensorflow as tf

# build model architecture 
model = Sequential() 

model.add(vgg_model) 
model.add(Dense(1024, activation='relu', input_dim=input_shape)) 
#model.add(Dropout(0.25)) 
model.add(Dense(512, activation='relu')) 
#model.add(Dropout(0.25))
model.add(Dense(256, activation='relu')) 
#model.add(Dropout(0.25))
model.add(Dense(num_class, activation='sigmoid'))

model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.001, momentum=0.9), 
      loss = tf.keras.losses.CategoricalCrossentropy(from_logits = True), 
      metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 18432)             7635264
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              18875392
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 27,167,555
# Trainable params: 27,167,555
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train, steps_per_epoch=8, 
                              epochs=100,  
                              validation_data=val,   
                              validation_steps=8,  
                              verbose=1)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 5s 678ms/step - loss: 1.0616 - accuracy: 0.4688 - f1_m: 0.3392 - precision_m: 0.5139 - recall_m: 0.2578 - val_loss: 1.0047 - val_accuracy: 0.4375 - val_f1_m: 0.4179 - val_precision_m: 0.5602 - val_recall_m: 0.3398
# Epoch 2/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.9789 - accuracy: 0.5234 - f1_m: 0.4859 - precision_m: 0.6736 - recall_m: 0.3906 - val_loss: 0.9017 - val_accuracy: 0.5664 - val_f1_m: 0.5975 - val_precision_m: 0.6538 - val_recall_m: 0.5586
# Epoch 3/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.9476 - accuracy: 0.5430 - f1_m: 0.5449 - precision_m: 0.6714 - recall_m: 0.4727 - val_loss: 0.9232 - val_accuracy: 0.6680 - val_f1_m: 0.4618 - val_precision_m: 0.8122 - val_recall_m: 0.3242
# Epoch 4/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.9471 - accuracy: 0.5352 - f1_m: 0.5291 - precision_m: 0.6585 - recall_m: 0.4648 - val_loss: 0.9855 - val_accuracy: 0.5664 - val_f1_m: 0.5596 - val_precision_m: 0.6309 - val_recall_m: 0.5039
# Epoch 5/100
# 8/8 [==============================] - 1s 140ms/step - loss: 0.9129 - accuracy: 0.6133 - f1_m: 0.5676 - precision_m: 0.6893 - recall_m: 0.4883 - val_loss: 0.9528 - val_accuracy: 0.6406 - val_f1_m: 0.5381 - val_precision_m: 0.6925 - val_recall_m: 0.4414
# Epoch 6/100
# 8/8 [==============================] - 1s 139ms/step - loss: 0.8864 - accuracy: 0.7109 - f1_m: 0.6089 - precision_m: 0.6650 - recall_m: 0.5898 - val_loss: 0.7223 - val_accuracy: 0.7852 - val_f1_m: 0.7470 - val_precision_m: 0.6483 - val_recall_m: 0.8828
# Epoch 7/100
# 8/8 [==============================] - 1s 136ms/step - loss: 0.7897 - accuracy: 0.7773 - f1_m: 0.7470 - precision_m: 0.6672 - recall_m: 0.8555 - val_loss: 0.8175 - val_accuracy: 0.7617 - val_f1_m: 0.7402 - val_precision_m: 0.7639 - val_recall_m: 0.7188
# Epoch 8/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.7633 - accuracy: 0.8086 - f1_m: 0.7877 - precision_m: 0.8047 - recall_m: 0.7773 - val_loss: 0.7250 - val_accuracy: 0.7930 - val_f1_m: 0.7766 - val_precision_m: 0.7051 - val_recall_m: 0.8672
# Epoch 9/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.7877 - accuracy: 0.7539 - f1_m: 0.7570 - precision_m: 0.6950 - recall_m: 0.8320 - val_loss: 0.8261 - val_accuracy: 0.6445 - val_f1_m: 0.6662 - val_precision_m: 0.6163 - val_recall_m: 0.7266
# Epoch 10/100
# 8/8 [==============================] - 1s 137ms/step - loss: 0.8674 - accuracy: 0.6445 - f1_m: 0.6734 - precision_m: 0.6030 - recall_m: 0.7656 - val_loss: 0.9129 - val_accuracy: 0.5039 - val_f1_m: 0.6172 - val_precision_m: 0.5349 - val_recall_m: 0.7305
# Epoch 11/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.9307 - accuracy: 0.5664 - f1_m: 0.6200 - precision_m: 0.5007 - recall_m: 0.8203 - val_loss: 0.9606 - val_accuracy: 0.6055 - val_f1_m: 0.6437 - val_precision_m: 0.5110 - val_recall_m: 0.8711
# Epoch 12/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.8414 - accuracy: 0.6953 - f1_m: 0.6821 - precision_m: 0.5601 - recall_m: 0.8750 - val_loss: 0.7673 - val_accuracy: 0.7500 - val_f1_m: 0.7306 - val_precision_m: 0.6404 - val_recall_m: 0.8516
# Epoch 13/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.7751 - accuracy: 0.7695 - f1_m: 0.7539 - precision_m: 0.6910 - recall_m: 0.8320 - val_loss: 0.6866 - val_accuracy: 0.7734 - val_f1_m: 0.7784 - val_precision_m: 0.7666 - val_recall_m: 0.7930
# Epoch 14/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7357 - accuracy: 0.8125 - f1_m: 0.8172 - precision_m: 0.8115 - recall_m: 0.8242 - val_loss: 0.7757 - val_accuracy: 0.8008 - val_f1_m: 0.7780 - val_precision_m: 0.7434 - val_recall_m: 0.8164
# Epoch 15/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7420 - accuracy: 0.7891 - f1_m: 0.8004 - precision_m: 0.7772 - recall_m: 0.8281 - val_loss: 0.7027 - val_accuracy: 0.7891 - val_f1_m: 0.7812 - val_precision_m: 0.7692 - val_recall_m: 0.7969
# Epoch 16/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.8004 - accuracy: 0.7344 - f1_m: 0.7407 - precision_m: 0.6878 - recall_m: 0.8047 - val_loss: 0.7146 - val_accuracy: 0.8047 - val_f1_m: 0.7871 - val_precision_m: 0.7062 - val_recall_m: 0.8906
# Epoch 17/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.7827 - accuracy: 0.7539 - f1_m: 0.7473 - precision_m: 0.6841 - recall_m: 0.8242 - val_loss: 0.6936 - val_accuracy: 0.8750 - val_f1_m: 0.8367 - val_precision_m: 0.7699 - val_recall_m: 0.9180
# Epoch 18/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7486 - accuracy: 0.7852 - f1_m: 0.7868 - precision_m: 0.7208 - recall_m: 0.8672 - val_loss: 0.7434 - val_accuracy: 0.8281 - val_f1_m: 0.8069 - val_precision_m: 0.7529 - val_recall_m: 0.8711
# Epoch 19/100
# 8/8 [==============================] - 1s 135ms/step - loss: 0.7441 - accuracy: 0.8203 - f1_m: 0.7985 - precision_m: 0.7481 - recall_m: 0.8594 - val_loss: 0.7440 - val_accuracy: 0.8242 - val_f1_m: 0.8088 - val_precision_m: 0.7863 - val_recall_m: 0.8359
# Epoch 20/100
# 8/8 [==============================] - 1s 135ms/step - loss: 0.7538 - accuracy: 0.7773 - f1_m: 0.7850 - precision_m: 0.7439 - recall_m: 0.8320 - val_loss: 0.6691 - val_accuracy: 0.8125 - val_f1_m: 0.8186 - val_precision_m: 0.7883 - val_recall_m: 0.8555
# Epoch 21/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7163 - accuracy: 0.8359 - f1_m: 0.8224 - precision_m: 0.7861 - recall_m: 0.8633 - val_loss: 0.6794 - val_accuracy: 0.8516 - val_f1_m: 0.8379 - val_precision_m: 0.8047 - val_recall_m: 0.8750
# Epoch 22/100
# 8/8 [==============================] - 1s 152ms/step - loss: 0.7032 - accuracy: 0.8477 - f1_m: 0.8461 - precision_m: 0.8163 - recall_m: 0.8789 - val_loss: 0.7537 - val_accuracy: 0.8712 - val_f1_m: 0.8775 - val_precision_m: 0.8585 - val_recall_m: 0.8984
# Epoch 23/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.7098 - accuracy: 0.8281 - f1_m: 0.8321 - precision_m: 0.7830 - recall_m: 0.8906 - val_loss: 0.7088 - val_accuracy: 0.8555 - val_f1_m: 0.8420 - val_precision_m: 0.7814 - val_recall_m: 0.9141
# Epoch 24/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.7262 - accuracy: 0.8086 - f1_m: 0.8026 - precision_m: 0.7520 - recall_m: 0.8633 - val_loss: 0.7708 - val_accuracy: 0.8477 - val_f1_m: 0.8276 - val_precision_m: 0.7798 - val_recall_m: 0.8828
# Epoch 25/100
# 8/8 [==============================] - 1s 121ms/step - loss: 0.7654 - accuracy: 0.7500 - f1_m: 0.7735 - precision_m: 0.7173 - recall_m: 0.8398 - val_loss: 0.6981 - val_accuracy: 0.8594 - val_f1_m: 0.8476 - val_precision_m: 0.7911 - val_recall_m: 0.9141
# Epoch 26/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.6960 - accuracy: 0.8633 - f1_m: 0.8309 - precision_m: 0.7647 - recall_m: 0.9102 - val_loss: 0.6979 - val_accuracy: 0.8125 - val_f1_m: 0.8010 - val_precision_m: 0.7420 - val_recall_m: 0.8711
# Epoch 27/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7261 - accuracy: 0.8164 - f1_m: 0.8143 - precision_m: 0.7644 - recall_m: 0.8750 - val_loss: 0.7232 - val_accuracy: 0.8203 - val_f1_m: 0.7889 - val_precision_m: 0.7344 - val_recall_m: 0.8555
# Epoch 28/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7330 - accuracy: 0.7930 - f1_m: 0.8038 - precision_m: 0.7498 - recall_m: 0.8672 - val_loss: 0.7147 - val_accuracy: 0.8516 - val_f1_m: 0.8175 - val_precision_m: 0.7714 - val_recall_m: 0.8711
# Epoch 29/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7085 - accuracy: 0.8320 - f1_m: 0.8307 - precision_m: 0.7822 - recall_m: 0.8867 - val_loss: 0.6454 - val_accuracy: 0.8398 - val_f1_m: 0.8229 - val_precision_m: 0.7545 - val_recall_m: 0.9062
# Epoch 30/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7028 - accuracy: 0.8359 - f1_m: 0.8261 - precision_m: 0.7651 - recall_m: 0.8984 - val_loss: 0.6469 - val_accuracy: 0.8477 - val_f1_m: 0.8506 - val_precision_m: 0.8086 - val_recall_m: 0.8984
# Epoch 31/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6872 - accuracy: 0.8594 - f1_m: 0.8577 - precision_m: 0.8348 - recall_m: 0.8828 - val_loss: 0.6412 - val_accuracy: 0.8789 - val_f1_m: 0.8597 - val_precision_m: 0.8384 - val_recall_m: 0.8828
# Epoch 32/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7306 - accuracy: 0.8086 - f1_m: 0.8116 - precision_m: 0.7900 - recall_m: 0.8359 - val_loss: 0.6943 - val_accuracy: 0.8789 - val_f1_m: 0.8789 - val_precision_m: 0.8544 - val_recall_m: 0.9062
# Epoch 33/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.6944 - accuracy: 0.8516 - f1_m: 0.8353 - precision_m: 0.7936 - recall_m: 0.8828 - val_loss: 0.7014 - val_accuracy: 0.8359 - val_f1_m: 0.8278 - val_precision_m: 0.7960 - val_recall_m: 0.8633
# Epoch 34/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7546 - accuracy: 0.8047 - f1_m: 0.7899 - precision_m: 0.7657 - recall_m: 0.8164 - val_loss: 0.7409 - val_accuracy: 0.8359 - val_f1_m: 0.8326 - val_precision_m: 0.7921 - val_recall_m: 0.8789
# Epoch 35/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.6615 - accuracy: 0.8984 - f1_m: 0.8719 - precision_m: 0.8375 - recall_m: 0.9102 - val_loss: 0.6765 - val_accuracy: 0.8867 - val_f1_m: 0.8642 - val_precision_m: 0.8348 - val_recall_m: 0.8984
# Epoch 36/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7181 - accuracy: 0.8086 - f1_m: 0.8300 - precision_m: 0.8136 - recall_m: 0.8477 - val_loss: 0.6031 - val_accuracy: 0.8984 - val_f1_m: 0.8927 - val_precision_m: 0.8593 - val_recall_m: 0.9297
# Epoch 37/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.6603 - accuracy: 0.8984 - f1_m: 0.8777 - precision_m: 0.8482 - recall_m: 0.9102 - val_loss: 0.7010 - val_accuracy: 0.8516 - val_f1_m: 0.8397 - val_precision_m: 0.8050 - val_recall_m: 0.8789
# Epoch 38/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.7378 - accuracy: 0.7930 - f1_m: 0.8003 - precision_m: 0.7897 - recall_m: 0.8125 - val_loss: 0.6904 - val_accuracy: 0.8242 - val_f1_m: 0.8202 - val_precision_m: 0.8022 - val_recall_m: 0.8398
# Epoch 39/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7035 - accuracy: 0.8438 - f1_m: 0.8281 - precision_m: 0.8148 - recall_m: 0.8438 - val_loss: 0.7225 - val_accuracy: 0.8828 - val_f1_m: 0.8602 - val_precision_m: 0.8312 - val_recall_m: 0.8945
# Epoch 40/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7072 - accuracy: 0.8359 - f1_m: 0.8414 - precision_m: 0.8382 - recall_m: 0.8477 - val_loss: 0.7284 - val_accuracy: 0.8398 - val_f1_m: 0.8270 - val_precision_m: 0.7789 - val_recall_m: 0.8828
# Epoch 41/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6843 - accuracy: 0.8672 - f1_m: 0.8546 - precision_m: 0.7970 - recall_m: 0.9219 - val_loss: 0.7039 - val_accuracy: 0.8516 - val_f1_m: 0.8411 - val_precision_m: 0.7973 - val_recall_m: 0.8906
# Epoch 42/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7222 - accuracy: 0.8281 - f1_m: 0.8026 - precision_m: 0.7418 - recall_m: 0.8750 - val_loss: 0.6217 - val_accuracy: 0.8828 - val_f1_m: 0.8608 - val_precision_m: 0.7967 - val_recall_m: 0.9375
# Epoch 43/100
# 8/8 [==============================] - 1s 138ms/step - loss: 0.7151 - accuracy: 0.8281 - f1_m: 0.8212 - precision_m: 0.7722 - recall_m: 0.8789 - val_loss: 0.7195 - val_accuracy: 0.8584 - val_f1_m: 0.8653 - val_precision_m: 0.8195 - val_recall_m: 0.9180
# Epoch 44/100
# 8/8 [==============================] - 2s 238ms/step - loss: 0.7081 - accuracy: 0.8230 - f1_m: 0.8230 - precision_m: 0.7777 - recall_m: 0.8748 - val_loss: 0.7220 - val_accuracy: 0.8594 - val_f1_m: 0.8569 - val_precision_m: 0.7922 - val_recall_m: 0.9336
# Epoch 45/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.7031 - accuracy: 0.8438 - f1_m: 0.8380 - precision_m: 0.7864 - recall_m: 0.8984 - val_loss: 0.6607 - val_accuracy: 0.8906 - val_f1_m: 0.8743 - val_precision_m: 0.8325 - val_recall_m: 0.9219
# Epoch 46/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6971 - accuracy: 0.8477 - f1_m: 0.8390 - precision_m: 0.7999 - recall_m: 0.8828 - val_loss: 0.7420 - val_accuracy: 0.8867 - val_f1_m: 0.8629 - val_precision_m: 0.8190 - val_recall_m: 0.9141
# Epoch 47/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.6775 - accuracy: 0.8828 - f1_m: 0.8634 - precision_m: 0.8186 - recall_m: 0.9141 - val_loss: 0.6270 - val_accuracy: 0.8828 - val_f1_m: 0.8770 - val_precision_m: 0.8342 - val_recall_m: 0.9258
# Epoch 48/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.6488 - accuracy: 0.8906 - f1_m: 0.8909 - precision_m: 0.8493 - recall_m: 0.9375 - val_loss: 0.6670 - val_accuracy: 0.8711 - val_f1_m: 0.8484 - val_precision_m: 0.8076 - val_recall_m: 0.8945
# Epoch 49/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6818 - accuracy: 0.8555 - f1_m: 0.8603 - precision_m: 0.8200 - recall_m: 0.9062 - val_loss: 0.6468 - val_accuracy: 0.8594 - val_f1_m: 0.8517 - val_precision_m: 0.8137 - val_recall_m: 0.8945
# Epoch 50/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6635 - accuracy: 0.9062 - f1_m: 0.8848 - precision_m: 0.8615 - recall_m: 0.9102 - val_loss: 0.6313 - val_accuracy: 0.8867 - val_f1_m: 0.8803 - val_precision_m: 0.8429 - val_recall_m: 0.9219
# Epoch 51/100
# 8/8 [==============================] - 1s 127ms/step - loss: 0.6982 - accuracy: 0.8477 - f1_m: 0.8339 - precision_m: 0.7978 - recall_m: 0.8750 - val_loss: 0.6745 - val_accuracy: 0.8984 - val_f1_m: 0.8712 - val_precision_m: 0.8362 - val_recall_m: 0.9102
# Epoch 52/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.7148 - accuracy: 0.8242 - f1_m: 0.8247 - precision_m: 0.7843 - recall_m: 0.8711 - val_loss: 0.6525 - val_accuracy: 0.8438 - val_f1_m: 0.8377 - val_precision_m: 0.7839 - val_recall_m: 0.9023
# Epoch 53/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7273 - accuracy: 0.8281 - f1_m: 0.8112 - precision_m: 0.7555 - recall_m: 0.8789 - val_loss: 0.7594 - val_accuracy: 0.8438 - val_f1_m: 0.8358 - val_precision_m: 0.7978 - val_recall_m: 0.8789
# Epoch 54/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.6779 - accuracy: 0.8633 - f1_m: 0.8648 - precision_m: 0.8288 - recall_m: 0.9062 - val_loss: 0.6832 - val_accuracy: 0.8125 - val_f1_m: 0.7939 - val_precision_m: 0.7306 - val_recall_m: 0.8711
# Epoch 55/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.6877 - accuracy: 0.8438 - f1_m: 0.8422 - precision_m: 0.7821 - recall_m: 0.9141 - val_loss: 0.7206 - val_accuracy: 0.8477 - val_f1_m: 0.8436 - val_precision_m: 0.7710 - val_recall_m: 0.9336
# Epoch 56/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.7056 - accuracy: 0.8477 - f1_m: 0.8248 - precision_m: 0.7525 - recall_m: 0.9141 - val_loss: 0.7233 - val_accuracy: 0.8594 - val_f1_m: 0.8124 - val_precision_m: 0.7292 - val_recall_m: 0.9180
# Epoch 57/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6926 - accuracy: 0.8477 - f1_m: 0.8314 - precision_m: 0.7641 - recall_m: 0.9141 - val_loss: 0.6559 - val_accuracy: 0.8984 - val_f1_m: 0.8793 - val_precision_m: 0.8385 - val_recall_m: 0.9258
# Epoch 58/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.6798 - accuracy: 0.8711 - f1_m: 0.8581 - precision_m: 0.8186 - recall_m: 0.9023 - val_loss: 0.6434 - val_accuracy: 0.8633 - val_f1_m: 0.8436 - val_precision_m: 0.7984 - val_recall_m: 0.8945
# Epoch 59/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6979 - accuracy: 0.8438 - f1_m: 0.8366 - precision_m: 0.7894 - recall_m: 0.8906 - val_loss: 0.7158 - val_accuracy: 0.9180 - val_f1_m: 0.8878 - val_precision_m: 0.8531 - val_recall_m: 0.9258
# Epoch 60/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.7234 - accuracy: 0.8242 - f1_m: 0.8205 - precision_m: 0.7824 - recall_m: 0.8633 - val_loss: 0.6851 - val_accuracy: 0.9219 - val_f1_m: 0.9107 - val_precision_m: 0.8795 - val_recall_m: 0.9453
# Epoch 61/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7064 - accuracy: 0.8320 - f1_m: 0.8295 - precision_m: 0.7834 - recall_m: 0.8828 - val_loss: 0.6647 - val_accuracy: 0.9062 - val_f1_m: 0.8857 - val_precision_m: 0.8494 - val_recall_m: 0.9258
# Epoch 62/100
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6482 - accuracy: 0.8945 - f1_m: 0.8944 - precision_m: 0.8554 - recall_m: 0.9375 - val_loss: 0.7198 - val_accuracy: 0.8867 - val_f1_m: 0.8692 - val_precision_m: 0.8351 - val_recall_m: 0.9062
# Epoch 63/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.7274 - accuracy: 0.8164 - f1_m: 0.8081 - precision_m: 0.7764 - recall_m: 0.8438 - val_loss: 0.6776 - val_accuracy: 0.9062 - val_f1_m: 0.8840 - val_precision_m: 0.8498 - val_recall_m: 0.9219
# Epoch 64/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7085 - accuracy: 0.8398 - f1_m: 0.8277 - precision_m: 0.7863 - recall_m: 0.8750 - val_loss: 0.6911 - val_accuracy: 0.8712 - val_f1_m: 0.8657 - val_precision_m: 0.8344 - val_recall_m: 0.9002
# Epoch 65/100
# 8/8 [==============================] - 1s 126ms/step - loss: 0.6726 - accuracy: 0.8672 - f1_m: 0.8706 - precision_m: 0.8350 - recall_m: 0.9102 - val_loss: 0.6815 - val_accuracy: 0.8906 - val_f1_m: 0.8926 - val_precision_m: 0.8698 - val_recall_m: 0.9180
# Epoch 66/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.6906 - accuracy: 0.8633 - f1_m: 0.8446 - precision_m: 0.8210 - recall_m: 0.8711 - val_loss: 0.6088 - val_accuracy: 0.8555 - val_f1_m: 0.8603 - val_precision_m: 0.8365 - val_recall_m: 0.8867
# Epoch 67/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.6902 - accuracy: 0.8398 - f1_m: 0.8465 - precision_m: 0.8145 - recall_m: 0.8828 - val_loss: 0.6324 - val_accuracy: 0.8672 - val_f1_m: 0.8634 - val_precision_m: 0.8124 - val_recall_m: 0.9219
# Epoch 68/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.6424 - accuracy: 0.9258 - f1_m: 0.8939 - precision_m: 0.8395 - recall_m: 0.9570 - val_loss: 0.6643 - val_accuracy: 0.8867 - val_f1_m: 0.8889 - val_precision_m: 0.8459 - val_recall_m: 0.9375
# Epoch 69/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.7039 - accuracy: 0.8477 - f1_m: 0.8326 - precision_m: 0.7893 - recall_m: 0.8828 - val_loss: 0.6698 - val_accuracy: 0.9062 - val_f1_m: 0.8860 - val_precision_m: 0.8716 - val_recall_m: 0.9023
# Epoch 70/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7225 - accuracy: 0.8203 - f1_m: 0.8132 - precision_m: 0.7928 - recall_m: 0.8359 - val_loss: 0.6661 - val_accuracy: 0.8633 - val_f1_m: 0.8482 - val_precision_m: 0.8240 - val_recall_m: 0.8750
# Epoch 71/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7140 - accuracy: 0.8242 - f1_m: 0.8229 - precision_m: 0.7832 - recall_m: 0.8672 - val_loss: 0.5898 - val_accuracy: 0.9102 - val_f1_m: 0.9112 - val_precision_m: 0.9050 - val_recall_m: 0.9180
# Epoch 72/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.7039 - accuracy: 0.8164 - f1_m: 0.8356 - precision_m: 0.7844 - recall_m: 0.8945 - val_loss: 0.7227 - val_accuracy: 0.8594 - val_f1_m: 0.8472 - val_precision_m: 0.7931 - val_recall_m: 0.9102
# Epoch 73/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.7126 - accuracy: 0.8242 - f1_m: 0.8134 - precision_m: 0.7602 - recall_m: 0.8750 - val_loss: 0.6467 - val_accuracy: 0.8789 - val_f1_m: 0.8389 - val_precision_m: 0.7846 - val_recall_m: 0.9023
# Epoch 74/100
# 8/8 [==============================] - 1s 130ms/step - loss: 0.7160 - accuracy: 0.7969 - f1_m: 0.8144 - precision_m: 0.7595 - recall_m: 0.8789 - val_loss: 0.6875 - val_accuracy: 0.8398 - val_f1_m: 0.8313 - val_precision_m: 0.7554 - val_recall_m: 0.9258
# Epoch 75/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7057 - accuracy: 0.8398 - f1_m: 0.8251 - precision_m: 0.7672 - recall_m: 0.8945 - val_loss: 0.6663 - val_accuracy: 0.8789 - val_f1_m: 0.8580 - val_precision_m: 0.8064 - val_recall_m: 0.9180
# Epoch 76/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7108 - accuracy: 0.8125 - f1_m: 0.8231 - precision_m: 0.7602 - recall_m: 0.8984 - val_loss: 0.7118 - val_accuracy: 0.8828 - val_f1_m: 0.8592 - val_precision_m: 0.8028 - val_recall_m: 0.9258
# Epoch 77/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6875 - accuracy: 0.8477 - f1_m: 0.8578 - precision_m: 0.8030 - recall_m: 0.9219 - val_loss: 0.6600 - val_accuracy: 0.8984 - val_f1_m: 0.8809 - val_precision_m: 0.8378 - val_recall_m: 0.9297
# Epoch 78/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6840 - accuracy: 0.8711 - f1_m: 0.8493 - precision_m: 0.7878 - recall_m: 0.9219 - val_loss: 0.7139 - val_accuracy: 0.8828 - val_f1_m: 0.8503 - val_precision_m: 0.7824 - val_recall_m: 0.9336
# Epoch 79/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.6774 - accuracy: 0.8633 - f1_m: 0.8572 - precision_m: 0.8024 - recall_m: 0.9219 - val_loss: 0.6609 - val_accuracy: 0.8906 - val_f1_m: 0.8783 - val_precision_m: 0.8274 - val_recall_m: 0.9375
# Epoch 80/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6809 - accuracy: 0.8711 - f1_m: 0.8554 - precision_m: 0.7967 - recall_m: 0.9258 - val_loss: 0.6457 - val_accuracy: 0.9062 - val_f1_m: 0.8825 - val_precision_m: 0.8380 - val_recall_m: 0.9336
# Epoch 81/100
# 8/8 [==============================] - 1s 128ms/step - loss: 0.6846 - accuracy: 0.8594 - f1_m: 0.8577 - precision_m: 0.8176 - recall_m: 0.9023 - val_loss: 0.6461 - val_accuracy: 0.8906 - val_f1_m: 0.8840 - val_precision_m: 0.8406 - val_recall_m: 0.9336
# Epoch 82/100
# 8/8 [==============================] - 1s 133ms/step - loss: 0.6794 - accuracy: 0.8750 - f1_m: 0.8608 - precision_m: 0.8208 - recall_m: 0.9062 - val_loss: 0.6047 - val_accuracy: 0.8516 - val_f1_m: 0.8653 - val_precision_m: 0.8254 - val_recall_m: 0.9102
# Epoch 83/100
# 8/8 [==============================] - 1s 129ms/step - loss: 0.6856 - accuracy: 0.8555 - f1_m: 0.8525 - precision_m: 0.8216 - recall_m: 0.8867 - val_loss: 0.7679 - val_accuracy: 0.8203 - val_f1_m: 0.8063 - val_precision_m: 0.7665 - val_recall_m: 0.8516
# Epoch 84/100
# 8/8 [==============================] - 1s 134ms/step - loss: 0.7466 - accuracy: 0.7930 - f1_m: 0.7921 - precision_m: 0.7506 - recall_m: 0.8398 - val_loss: 0.6893 - val_accuracy: 0.9023 - val_f1_m: 0.8882 - val_precision_m: 0.8448 - val_recall_m: 0.9375
# Epoch 85/100
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6917 - accuracy: 0.8398 - f1_m: 0.8456 - precision_m: 0.7991 - recall_m: 0.8984 - val_loss: 0.6732 - val_accuracy: 0.8927 - val_f1_m: 0.8662 - val_precision_m: 0.8265 - val_recall_m: 0.9119
# Epoch 86/100
# 8/8 [==============================] - 1s 110ms/step - loss: 0.6551 - accuracy: 0.8945 - f1_m: 0.8867 - precision_m: 0.8484 - recall_m: 0.9297 - val_loss: 0.6020 - val_accuracy: 0.8828 - val_f1_m: 0.8695 - val_precision_m: 0.8270 - val_recall_m: 0.9180
# Epoch 87/100
# 8/8 [==============================] - 1s 108ms/step - loss: 0.6611 - accuracy: 0.8789 - f1_m: 0.8768 - precision_m: 0.8403 - recall_m: 0.9180 - val_loss: 0.6681 - val_accuracy: 0.8711 - val_f1_m: 0.8548 - val_precision_m: 0.8130 - val_recall_m: 0.9023
# Epoch 88/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.7023 - accuracy: 0.8555 - f1_m: 0.8250 - precision_m: 0.7812 - recall_m: 0.8750 - val_loss: 0.7288 - val_accuracy: 0.8516 - val_f1_m: 0.8517 - val_precision_m: 0.8125 - val_recall_m: 0.8984
# Epoch 89/100
# 8/8 [==============================] - 1s 108ms/step - loss: 0.6852 - accuracy: 0.8516 - f1_m: 0.8602 - precision_m: 0.8328 - recall_m: 0.8906 - val_loss: 0.6376 - val_accuracy: 0.8867 - val_f1_m: 0.8766 - val_precision_m: 0.8464 - val_recall_m: 0.9102
# Epoch 90/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.6583 - accuracy: 0.8945 - f1_m: 0.8755 - precision_m: 0.8385 - recall_m: 0.9180 - val_loss: 0.6303 - val_accuracy: 0.9102 - val_f1_m: 0.8949 - val_precision_m: 0.8879 - val_recall_m: 0.9023
# Epoch 91/100
# 8/8 [==============================] - 1s 115ms/step - loss: 0.6609 - accuracy: 0.8867 - f1_m: 0.8827 - precision_m: 0.8579 - recall_m: 0.9102 - val_loss: 0.6152 - val_accuracy: 0.8711 - val_f1_m: 0.8615 - val_precision_m: 0.8186 - val_recall_m: 0.9102
# Epoch 92/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.6742 - accuracy: 0.8633 - f1_m: 0.8636 - precision_m: 0.8221 - recall_m: 0.9102 - val_loss: 0.7193 - val_accuracy: 0.8906 - val_f1_m: 0.8794 - val_precision_m: 0.8512 - val_recall_m: 0.9102
# Epoch 93/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.6465 - accuracy: 0.9102 - f1_m: 0.8955 - precision_m: 0.8574 - recall_m: 0.9375 - val_loss: 0.6095 - val_accuracy: 0.8750 - val_f1_m: 0.8816 - val_precision_m: 0.8665 - val_recall_m: 0.8984
# Epoch 94/100
# 8/8 [==============================] - 1s 113ms/step - loss: 0.6520 - accuracy: 0.8867 - f1_m: 0.8880 - precision_m: 0.8502 - recall_m: 0.9297 - val_loss: 0.6821 - val_accuracy: 0.8750 - val_f1_m: 0.8693 - val_precision_m: 0.8175 - val_recall_m: 0.9297
# Epoch 95/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6642 - accuracy: 0.8828 - f1_m: 0.8804 - precision_m: 0.8438 - recall_m: 0.9219 - val_loss: 0.6356 - val_accuracy: 0.9297 - val_f1_m: 0.9079 - val_precision_m: 0.8774 - val_recall_m: 0.9414
# Epoch 96/100
# 8/8 [==============================] - 1s 112ms/step - loss: 0.6982 - accuracy: 0.8438 - f1_m: 0.8405 - precision_m: 0.8035 - recall_m: 0.8828 - val_loss: 0.6206 - val_accuracy: 0.8125 - val_f1_m: 0.8247 - val_precision_m: 0.7935 - val_recall_m: 0.8594
# Epoch 97/100
# 8/8 [==============================] - 1s 111ms/step - loss: 0.6686 - accuracy: 0.8789 - f1_m: 0.8685 - precision_m: 0.8374 - recall_m: 0.9023 - val_loss: 0.6619 - val_accuracy: 0.8984 - val_f1_m: 0.8959 - val_precision_m: 0.8863 - val_recall_m: 0.9062
# Epoch 98/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6438 - accuracy: 0.9102 - f1_m: 0.9043 - precision_m: 0.8849 - recall_m: 0.9258 - val_loss: 0.6865 - val_accuracy: 0.8906 - val_f1_m: 0.8949 - val_precision_m: 0.8704 - val_recall_m: 0.9219
# Epoch 99/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6704 - accuracy: 0.8828 - f1_m: 0.8715 - precision_m: 0.8502 - recall_m: 0.8945 - val_loss: 0.6690 - val_accuracy: 0.8711 - val_f1_m: 0.8611 - val_precision_m: 0.8281 - val_recall_m: 0.8984
# Epoch 100/100
# 8/8 [==============================] - 1s 109ms/step - loss: 0.6678 - accuracy: 0.8750 - f1_m: 0.8608 - precision_m: 0.8335 - recall_m: 0.8906 - val_loss: 0.6274 - val_accuracy: 0.8828 - val_f1_m: 0.8658 - val_precision_m: 0.8148 - val_recall_m: 0.9258

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['f1_m'])
plt.plot(history.history['val_f1_m'])
plt.title('F1 Score')
plt.ylabel('f1')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['precision_m'])
plt.plot(history.history['val_precision_m'])
plt.title('Precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['recall_m'])
plt.plot(history.history['val_recall_m'])
plt.title('Recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
test_eval = model.evaluate(test, verbose=1)
print('El modelo predice el ', test_eval[1]*100,'% de los datos')
# Out:
# 213/213 [==============================] - 28s 131ms/step
# El modelo predice el  88.4796679019928 % de los datos

# %%
articulo_dir='D:/Documentos/Estudio/Maestría/Aprendizaje_Computacional/Implementacion/Deteccion_Articulo/dataset,solocovid,pneumonia'
#Para el conjunto del artículo
articulo_generator = train_datagen.flow_from_directory(
    articulo_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical') # set as validation data
articulo=articulo_generator
# Out:
# Found 351 images belonging to 2 classes.

# %%
print('Utilizando el conjunto de datos del artículo para evaluar el modelo')
test_eval = model.evaluate(articulo, verbose=1)
print('El modelo predice el ', test_eval[1]*100,'% de los datos')
# Out:
# Utilizando el conjunto de datos del artículo para evaluar el modelo
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15376\713085297.py in <module>
#       1 print('Utilizando el conjunto de datos del artículo para evaluar el modelo')
# ----> 2 test_eval = model.evaluate(articulo, verbose=1)
#       3 print('El modelo predice el ', test_eval[1]*100,'% de los datos')
#
# ~\.conda\envs\tfGPU\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1336                 max_queue_size=max_queue_size,
#    1337                 workers=workers,
# -> 1338                 use_multiprocessing=use_multiprocessing)
#    1339
#    1340         # Case 2: Symbolic tensors or Numpy array-like.
#
# ~\.conda\envs\tfGPU\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\.conda\envs\tfGPU\lib\site-packages\keras\engine\training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1789             workers=workers,
#    1790             use_multiprocessing=use_multiprocessing,
# -> 1791             verbose=verbose)
#    1792
#    1793     @interfaces.legacy_generator_methods_support
#
# ~\.conda\envs\tfGPU\lib\site-packages\keras\engine\training_generator.py in evaluate_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     399             outs = model.test_on_batch(x, y,
#     400                                        sample_weight=sample_weight,
# --> 401                                        reset_metrics=False)
#     402             outs = to_list(outs)
#     403             outs_per_batch.append(outs)
#
# ~\.conda\envs\tfGPU\lib\site-packages\keras\engine\training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1557             ins = x + y + sample_weights
#    1558         self._make_test_function()
# -> 1559         outputs = self.test_function(ins)
#    1560
#    1561         if reset_metrics:
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\.conda\envs\tfGPU\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# ~\.conda\envs\tfGPU\lib\site-packages\six.py in raise_from(value, from_value)
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument:  logits and labels must be broadcastable: logits_size=[32,3] labels_size=[32,2]
# 	 [[node loss/dense_4_loss/categorical_crossentropy/softmax_cross_entropy_with_logits (defined at \.conda\envs\tfGPU\lib\site-packages\keras\backend\tensorflow_backend.py:3009) ]]
# 	 [[loss/dense_4_loss/categorical_crossentropy/weighted_loss/broadcast_weights/assert_broadcastable/AssertGuard/pivot_f/_15/_31]]
#   (1) Invalid argument:  logits and labels must be broadcastable: logits_size=[32,3] labels_size=[32,2]
# 	 [[node loss/dense_4_loss/categorical_crossentropy/softmax_cross_entropy_with_logits (defined at \.conda\envs\tfGPU\lib\site-packages\keras\backend\tensorflow_backend.py:3009) ]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_keras_scratch_graph_2007]
#
# Function call stack:
# keras_scratch_graph -> keras_scratch_graph

# %%
print('Utilizando el conjunto de datos de test para evaluar el modelo')
test_eval = model.evaluate(test, verbose=1)
print('El modelo predice el ', test_eval[1]*100,'% de los datos')
# Out:
# Utilizando el conjunto de datos de test para evaluar el modelo
# 142/142 [==============================] - 5s 35ms/step
# El modelo predice el  97.68467545509338 % de los datos

# %%
print('Utilizando el conjunto de datos de test para evaluar el modelo')
print('Loss: ',test_eval[0])
print('Accuracy: ',test_eval[1])
print('F1 Score: ',test_eval[2])
print('Precision: ',test_eval[3])
print('Recall: ',test_eval[4])
# Out:
# Utilizando el conjunto de datos de test para evaluar el modelo
# Loss:  0.3677098751068115
# Accuracy:  0.9768467545509338
# F1 Score:  0.97563636302948
# Precision:  0.9743842482566833
# Recall:  0.9770265817642212

# %%
print('Utilizando el conjunto de datos del artículo para evaluar el modelo')
test_eval = model.evaluate(articulo, verbose=1)
print('El modelo predice el ', test_eval[1]*100,'% de los datos')
# Out:
# Utilizando el conjunto de datos del artículo para evaluar el modelo
# 11/11 [==============================] - 4s 396ms/step
# El modelo predice el  90.59829115867615 % de los datos

# %%
print('Utilizando el conjunto de datos del artículo para evaluar el modelo')
print('Loss: ',test_eval[0])
print('Accuracy: ',test_eval[1])
print('F1 Score: ',test_eval[2])
print('Precision: ',test_eval[3])
print('Recall: ',test_eval[4])
# Out:
# Utilizando el conjunto de datos del artículo para evaluar el modelo
# Loss:  0.46321430802345276
# Accuracy:  0.9059829115867615
# F1 Score:  0.9023765921592712
# Precision:  0.8964685201644897
# Recall:  0.9086326956748962

# %%
pred=model.predict(articulo)

# %%
#Aquí sólo hago con  un predict con el modelo y los datos del artículo
import numpy as np
suma=0
for i in range (351):
    if np.argmax(pred[i])==0:
        suma=suma+1
print(suma)
# Out:
# 120
